# %% [markdown]
# ## After running Mesa Job, this notebook aim to explore the data

# %% [markdown]
# ### `1. First simulation:`
#
# ____

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
# open dataset - profiles simulations
star= pd.read_csv('../extracted_data/profiles.csv')

print(star.head(10))
# Out:
#    zone  mass      logR      logT    logRho      logP  x_mass_fraction_H  \
# 0     1  15.0  2.264899  3.617779 -8.391887  3.030026                0.7
# 1     2  15.0  2.264899  3.617779 -8.391886  3.030026                0.7
# 2     3  15.0  2.264899  3.617779 -8.391886  3.030027                0.7
# 3     4  15.0  2.264899  3.617779 -8.391884  3.030029                0.7
# 4     5  15.0  2.264899  3.617779 -8.391881  3.030032                0.7
# 5     6  15.0  2.264899  3.617780 -8.391875  3.030039                0.7
# 6     7  15.0  2.264899  3.617782 -8.391864  3.030052                0.7
# 7     8  15.0  2.264899  3.617785 -8.391841  3.030078                0.7
# 8     9  15.0  2.264899  3.617792 -8.391795  3.030131                0.7
# 9    10  15.0  2.264899  3.617805 -8.391702  3.030236                0.7
#
#    y_mass_fraction_He  z_mass_fraction_metals            pp  cno  tri_alpha
# 0                0.28                    0.02  5.948319e-28  0.0        0.0
# 1                0.28                    0.02  5.948323e-28  0.0        0.0
# 2                0.28                    0.02  5.948333e-28  0.0        0.0
# 3                0.28                    0.02  5.948353e-28  0.0        0.0
# 4                0.28                    0.02  5.948395e-28  0.0        0.0
# 5                0.28                    0.02  5.948477e-28  0.0        0.0
# 6                0.28                    0.02  5.948635e-28  0.0        0.0
# 7                0.28                    0.02  5.948951e-28  0.0        0.0
# 8                0.28                    0.02  5.949582e-28  0.0        0.0
# 9                0.28                    0.02  5.950845e-28  0.0        0.0

# %%
# info about the columns
star.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3925 entries, 0 to 3924
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   zone                    3925 non-null   int64
#  1   mass                    3925 non-null   float64
#  2   logR                    3925 non-null   float64
#  3   logT                    3925 non-null   float64
#  4   logRho                  3925 non-null   float64
#  5   logP                    3925 non-null   float64
#  6   x_mass_fraction_H       3925 non-null   float64
#  7   y_mass_fraction_He      3925 non-null   float64
#  8   z_mass_fraction_metals  3925 non-null   float64
#  9   pp                      3925 non-null   float64
#  10  cno                     3925 non-null   float64
#  11  tri_alpha               3925 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 368.1 KB
